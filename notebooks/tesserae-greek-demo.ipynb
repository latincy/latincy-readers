# %%
## Imports

from latincyreaders import GreekTesseraeReader, AnnotationLevel

from pprint import pprint

# %%
## Set up reader

# TOKENIZE level: fast, no OdyCy model needed
G = GreekTesseraeReader(annotation_level=AnnotationLevel.TOKENIZE)

# %% [markdown]
# ## Fileids

# %%
## First 10 filenames

files = G.fileids()[:10]
pprint(files)
# Out:
# ['achilles_tatius.leucippe_et_clitophon.tess',
#  'aelian.de_natura_animalium.tess',
#  'aelian.epistulae_rusticae.tess',
#  'aelian.varia_historia.tess',
#  'aelius_aristides.ars_rhetorica.tess',
#  'aelius_aristides.orationes.tess',
#  'aeschines.against_ctesiphon.tess',
#  'aeschines.against_timarchus.tess',
#  'aeschines.on_the_embassy.tess',
#  'aeschylus.agamemnon.tess']

# %%
# Get files by pattern match (regex)
files = G.fileids(match='homer')
pprint(files)
# Out:
# ['homer.iliad.part.1.tess',
#  'homer.iliad.part.2.tess',
#  'homer.iliad.part.3.tess',
#  'homer.iliad.part.4.tess',
#  'homer.iliad.part.5.tess',
#  'homer.iliad.part.6.tess',
#  'homer.iliad.part.7.tess',
#  'homer.iliad.part.8.tess',
#  'homer.iliad.part.9.tess',
#  'homer.iliad.part.10.tess',
#  'homer.iliad.part.11.tess',
#  'homer.iliad.part.12.tess',
#  'homer.iliad.part.13.tess',
#  'homer.iliad.part.14.tess',
#  'homer.iliad.part.15.tess',
#  'homer.iliad.part.16.tess',
#  'homer.iliad.part.17.tess',
#  'homer.iliad.part.18.tess',
#  'homer.iliad.part.19.tess',
#  'homer.iliad.part.20.tess',
#  'homer.iliad.part.21.tess',
#  'homer.iliad.part.22.tess',
#  'homer.iliad.part.23.tess',
#  'homer.iliad.part.24.tess',
#  'homer.odyssey.part.1.tess',
#  'homer.odyssey.part.2.tess',
#  'homer.odyssey.part.3.tess',
#  'homer.odyssey.part.4.tess',
#  'homer.odyssey.part.5.tess',
#  'homer.odyssey.part.6.tess',
#  'homer.odyssey.part.7.tess',
#  'homer.odyssey.part.8.tess',
#  'homer.odyssey.part.9.tess',
#  'homer.odyssey.part.10.tess',
#  'homer.odyssey.part.11.tess',
#  'homer.odyssey.part.12.tess',
#  'homer.odyssey.part.13.tess',
#  'homer.odyssey.part.14.tess',
#  'homer.odyssey.part.15.tess',
#  'homer.odyssey.part.16.tess',
#  'homer.odyssey.part.17.tess',
#  'homer.odyssey.part.18.tess',
#  'homer.odyssey.part.19.tess',
#  'homer.odyssey.part.20.tess',
#  'homer.odyssey.part.21.tess',
#  'homer.odyssey.part.22.tess',
#  'homer.odyssey.part.23.tess',
#  'homer.odyssey.part.24.tess']

# %%
# Get Homer's Iliad files
iliad_files = G.fileids(match=r'homer.*iliad')
pprint(iliad_files)
# Out:
# ['homer.iliad.part.1.tess',
#  'homer.iliad.part.2.tess',
#  'homer.iliad.part.3.tess',
#  'homer.iliad.part.4.tess',
#  'homer.iliad.part.5.tess',
#  'homer.iliad.part.6.tess',
#  'homer.iliad.part.7.tess',
#  'homer.iliad.part.8.tess',
#  'homer.iliad.part.9.tess',
#  'homer.iliad.part.10.tess',
#  'homer.iliad.part.11.tess',
#  'homer.iliad.part.12.tess',
#  'homer.iliad.part.13.tess',
#  'homer.iliad.part.14.tess',
#  'homer.iliad.part.15.tess',
#  'homer.iliad.part.16.tess',
#  'homer.iliad.part.17.tess',
#  'homer.iliad.part.18.tess',
#  'homer.iliad.part.19.tess',
#  'homer.iliad.part.20.tess',
#  'homer.iliad.part.21.tess',
#  'homer.iliad.part.22.tess',
#  'homer.iliad.part.23.tess',
#  'homer.iliad.part.24.tess']

# %%
# Get Homer's Odyssey files
odyssey_files = G.fileids(match=r'homer.*odyssey')
pprint(odyssey_files)
# Out:
# ['homer.odyssey.part.1.tess',
#  'homer.odyssey.part.2.tess',
#  'homer.odyssey.part.3.tess',
#  'homer.odyssey.part.4.tess',
#  'homer.odyssey.part.5.tess',
#  'homer.odyssey.part.6.tess',
#  'homer.odyssey.part.7.tess',
#  'homer.odyssey.part.8.tess',
#  'homer.odyssey.part.9.tess',
#  'homer.odyssey.part.10.tess',
#  'homer.odyssey.part.11.tess',
#  'homer.odyssey.part.12.tess',
#  'homer.odyssey.part.13.tess',
#  'homer.odyssey.part.14.tess',
#  'homer.odyssey.part.15.tess',
#  'homer.odyssey.part.16.tess',
#  'homer.odyssey.part.17.tess',
#  'homer.odyssey.part.18.tess',
#  'homer.odyssey.part.19.tess',
#  'homer.odyssey.part.20.tess',
#  'homer.odyssey.part.21.tess',
#  'homer.odyssey.part.22.tess',
#  'homer.odyssey.part.23.tess',
#  'homer.odyssey.part.24.tess']

# %%
# Other authors
files = G.fileids(match='sophocles')
pprint(files)
# Out:
# ['sophocles.ajax.tess',
#  'sophocles.antigone.tess',
#  'sophocles.electra.tess',
#  'sophocles.ichneutae.tess',
#  'sophocles.oedipus_at_colonus.tess',
#  'sophocles.oedipus_tyrannus.tess',
#  'sophocles.philoctetes.tess',
#  'sophocles.trachiniae.tess']

# %%
files = G.fileids(match='euripides')
pprint(files)
# Out:
# ['euripides.alcestis.tess',
#  'euripides.andromache.tess',
#  'euripides.bacchae.tess',
#  'euripides.cyclops.tess',
#  'euripides.electra.tess',
#  'euripides.hecuba.tess',
#  'euripides.helen.tess',
#  'euripides.heracleidae.tess',
#  'euripides.heracles.tess',
#  'euripides.hippolytus.tess',
#  'euripides.ion.tess',
#  'euripides.iphigenia_aulis.tess',
#  'euripides.iphigenia_tauris.tess',
#  'euripides.medea.tess',
#  'euripides.orestes.tess',
#  'euripides.phoenissae.tess',
#  'euripides.rhesus.tess',
#  'euripides.suppliants.tess',
#  'euripides.trojan_women.tess']

# %%
# Get all files
all_files = G.fileids()
print(f"Total files: {len(all_files)}")
# Out:
# Total files: 820

# %% [markdown]
# ## Texts by line (zero NLP overhead)

# %%
# texts_by_line() - fastest way to read Tesserae files
# Returns (citation, text) pairs with zero NLP processing

iliad_1 = iliad_files[0] if iliad_files else G.fileids(match='homer')[0]

for i, (citation, text) in enumerate(G.texts_by_line(iliad_1)):
    if i >= 10:
        break
    print(f"{citation}: {text[:70]}...")
# Out:
# <hom. il. 1.1>: μῆνιν ἄειδε θεὰ Πηληϊάδεω Ἀχιλῆος...
# <hom. il. 1.2>: οὐλομένην, ἣ μυρίʼ Ἀχαιοῖς ἄλγεʼ ἔθηκε,...
# <hom. il. 1.3>: πολλὰς δʼ ἰφθίμους ψυχὰς Ἄϊδι προί̈αψεν...
# <hom. il. 1.4>: ἡρώων, αὐτοὺς δὲ ἑλώρια τεῦχε κύνεσσιν...
# <hom. il. 1.5>: οἰωνοῖσί τε πᾶσι, Διὸς δʼ ἐτελείετο βουλή,...
# <hom. il. 1.6>: ἐξ οὗ δὴ τὰ πρῶτα διαστήτην ἐρίσαντε...
# <hom. il. 1.7>: Ἀτρεί̈δης τε ἄναξ ἀνδρῶν καὶ δῖος Ἀχιλλεύς....
# <hom. il. 1.8>: τίς τʼ ἄρ σφωε θεῶν ἔριδι ξυνέηκε μάχεσθαι;...
# <hom. il. 1.9>: Λητοῦς καὶ Διὸς υἱός: ὃ γὰρ βασιλῆϊ χολωθεὶς...
# <hom. il. 1.10>: νοῦσον ἀνὰ στρατὸν ὄρσε κακήν, ὀλέκοντο δὲ λαοί,...

# %%
# Raw text (entire document as one string)
iliad_1_text = next(G.texts(iliad_1))
print(f"Character count: {len(iliad_1_text)}")
print(f"Word count (approx): {len(iliad_1_text.split())}")
print(f"\nFirst 200 chars: {iliad_1_text[:200]}")
# Out:
# Character count: 27270
# Word count (approx): 4519
#
# First 200 chars: μῆνιν ἄειδε θεὰ Πηληϊάδεω Ἀχιλῆος οὐλομένην, ἣ μυρίʼ Ἀχαιοῖς ἄλγεʼ ἔθηκε, πολλὰς δʼ ἰφθίμους ψυχὰς Ἄϊδι προί̈αψεν ἡρώων, αὐτοὺς δὲ ἑλώρια τεῦχε κύνεσσιν οἰωνοῖσί τε πᾶσι, Διὸς δʼ ἐτελείετο βουλή, ἐξ ο

# %% [markdown]
# ## Doc structures

# %%
## Docs - spaCy Doc objects

iliad_doc = next(G.docs(iliad_1))
print(iliad_doc[:300])
# Out:
# μῆνιν ἄειδε θεὰ Πηληϊάδεω Ἀχιλῆος οὐλομένην, ἣ μυρίʼ Ἀχαιοῖς ἄλγεʼ ἔθηκε, πολλὰς δʼ ἰφθίμους ψυχὰς Ἄϊδι προί̈αψεν ἡρώων, αὐτοὺς δὲ ἑλώρια τεῦχε κύνεσσιν οἰωνοῖσί τε πᾶσι, Διὸς δʼ ἐτελείετο βουλή, ἐξ οὗ δὴ τὰ πρῶτα διαστήτην ἐρίσαντε Ἀτρεί̈δης τε ἄναξ ἀνδρῶν καὶ δῖος Ἀχιλλεύς. τίς τʼ ἄρ σφωε θεῶν ἔριδι ξυνέηκε μάχεσθαι; Λητοῦς καὶ Διὸς υἱός: ὃ γὰρ βασιλῆϊ χολωθεὶς νοῦσον ἀνὰ στρατὸν ὄρσε κακήν, ὀλέκοντο δὲ λαοί, οὕνεκα τὸν Χρύσην ἠτίμασεν ἀρητῆρα Ἀτρεί̈δης: ὃ γὰρ ἦλθε θοὰς ἐπὶ νῆας Ἀχαιῶν λυσόμενός τε θύγατρα φέρων τʼ ἀπερείσιʼ ἄποινα, στέμματʼ ἔχων ἐν χερσὶν ἑκηβόλου Ἀπόλλωνος χρυσέῳ ἀνὰ σκήπτρῳ, καὶ λίσσετο πάντας Ἀχαιούς, Ἀτρεί̈δα δὲ μάλιστα δύω, κοσμήτορε λαῶν: Ἀτρεί̈δαι τε καὶ ἄλλοι ἐϋκνήμιδες Ἀχαιοί, ὑμῖν μὲν θεοὶ δοῖεν Ὀλύμπια δώματʼ ἔχοντες ἐκπέρσαι Πριάμοιο πόλιν, εὖ δʼ οἴκαδʼ ἱκέσθαι: παῖδα δʼ ἐμοὶ λύσαιτε φίλην, τὰ δʼ ἄποινα δέχεσθαι, ἁζόμενοι Διὸς υἱὸν ἑκηβόλον Ἀπόλλωνα. ἔνθʼ ἄλλοι μὲν πάντες ἐπευφήμησαν Ἀχαιοὶ αἰδεῖσθαί θʼ ἱερῆα καὶ ἀγλαὰ δέχθαι ἄποινα: ἀλλʼ οὐκ Ἀτρεί̈δῃ Ἀγαμέμνονι ἥνδανε θυμῷ, ἀλλὰ κακῶς ἀφίει, κρατερὸν δʼ ἐπὶ μῦθον ἔτελλε: μή σε γέρον κοίλῃσιν ἐγὼ παρὰ νηυσὶ κιχείω ἢ νῦν δηθύνοντʼ ἢ ὕστερον αὖτις ἰόντα, μή νύ τοι οὐ χραίσμῃ σκῆπτρον καὶ στέμμα θεοῖο: τὴν δʼ ἐγὼ οὐ λύσω: πρίν μιν καὶ γῆρας ἔπεισιν ἡμετέρῳ ἐνὶ οἴκῳ ἐν Ἄργεϊ τηλόθι πάτρης ἱστὸν ἐποιχομένην καὶ ἐμὸν λέχος ἀντιόωσαν: ἀλλʼ ἴθι μή μʼ ἐρέθιζε σαώτερος ὥς κε νέηαι. ὣς ἔφατʼ, ἔδεισεν δʼ ὃ γέρων καὶ ἐπείθετο μύθῳ: βῆ δʼ ἀκέων παρὰ θῖνα πολυφλοίσβοιο θαλάσσης: πολλὰ δʼ ἔπειτʼ ἀπάνευθε κιὼν ἠρᾶθʼ ὃ γεραιὸς Ἀπόλλωνι ἄνακτι, τὸν ἠύ̈κομος τέκε Λητώ: κλῦθί μευ ἀργυρότοξʼ, ὃς Χρύσην ἀμφιβέβηκας Κίλλάν τε ζαθέην

# %%
## Doc Rows - citation -> text mapping

iliad_docrows = next(G.doc_rows(iliad_1))

print('First 10 citation -> span mappings:')
for i, (citation, span) in enumerate(iliad_docrows.items()):
    if i >= 10:
        break
    print(f"  {citation}: {span.text[:50]}...")
# Out:
# First 10 citation -> span mappings:
#   <hom. il. 1.1>: μῆνιν ἄειδε θεὰ Πηληϊάδεω Ἀχιλῆος οὐλομένην...
#   <hom. il. 1.2>: οὐλομένην, ἣ μυρίʼ Ἀχαιοῖς ἄλγεʼ ἔθηκε, πολλὰς δʼ ...
#   <hom. il. 1.3>: ψυχὰς Ἄϊδι προί̈αψεν ἡρώων, αὐτοὺς δὲ ἑλώρια τεῦχε...
#   <hom. il. 1.4>: τεῦχε κύνεσσιν οἰωνοῖσί τε πᾶσι, Διὸς δʼ ἐτελείετο...
#   <hom. il. 1.5>: βουλή, ἐξ οὗ δὴ τὰ πρῶτα διαστήτην ἐρίσαντε Ἀτρεί̈...
#   <hom. il. 1.6>: Ἀτρεί̈δης τε ἄναξ ἀνδρῶν καὶ δῖος Ἀχιλλεύς. τίς τʼ...
#   <hom. il. 1.7>: σφωε θεῶν ἔριδι ξυνέηκε μάχεσθαι; Λητοῦς καὶ Διὸς ...
#   <hom. il. 1.8>: υἱός: ὃ γὰρ βασιλῆϊ χολωθεὶς νοῦσον ἀνὰ στρατὸν ὄρ...
#   <hom. il. 1.9>: κακήν, ὀλέκοντο δὲ λαοί, οὕνεκα τὸν Χρύσην ἠτίμασε...
#   <hom. il. 1.10>: ἀρητῆρα Ἀτρεί̈δης: ὃ γὰρ ἦλθε θοὰς ἐπὶ νῆας Ἀχαιῶν...

# %% [markdown]
# ## Doc units

# %%
# Sents - spaCy Span objects

iliad_sents = G.sents(iliad_1)

for i in range(1, 6):
    print(f'Sent {i}: {next(iliad_sents)}')
    print()
# Out:
# Sent 1: μῆνιν ἄειδε θεὰ Πηληϊάδεω Ἀχιλῆος οὐλομένην, ἣ μυρίʼ Ἀχαιοῖς ἄλγεʼ ἔθηκε, πολλὰς δʼ ἰφθίμους ψυχὰς Ἄϊδι προί̈αψεν ἡρώων, αὐτοὺς δὲ ἑλώρια τεῦχε κύνεσσιν οἰωνοῖσί τε πᾶσι, Διὸς δʼ ἐτελείετο βουλή, ἐξ οὗ δὴ τὰ πρῶτα διαστήτην ἐρίσαντε Ἀτρεί̈δης τε ἄναξ ἀνδρῶν καὶ δῖος Ἀχιλλεύς.
#
# Sent 2: τίς τʼ ἄρ σφωε θεῶν ἔριδι ξυνέηκε μάχεσθαι;
#
# Sent 3: Λητοῦς καὶ Διὸς υἱός:
#
# Sent 4: ὃ γὰρ βασιλῆϊ χολωθεὶς νοῦσον ἀνὰ στρατὸν ὄρσε κακήν, ὀλέκοντο δὲ λαοί, οὕνεκα τὸν Χρύσην ἠτίμασεν ἀρητῆρα Ἀτρεί̈δης:
#
# Sent 5: ὃ γὰρ ἦλθε θοὰς ἐπὶ νῆας Ἀχαιῶν λυσόμενός τε θύγατρα φέρων τʼ ἀπερείσιʼ ἄποινα, στέμματʼ ἔχων ἐν χερσὶν ἑκηβόλου Ἀπόλλωνος χρυσέῳ ἀνὰ σκήπτρῳ, καὶ λίσσετο πάντας Ἀχαιούς, Ἀτρεί̈δα δὲ μάλιστα δύω, κοσμήτορε λαῶν:

# %%
# Tokens

iliad_tokens = G.tokens(iliad_1)

for i in range(1, 15):
    print(f'Word {i}: {next(iliad_tokens)}')
# Out:
# Word 1: μῆνιν
# Word 2: ἄειδε
# Word 3: θεὰ
# Word 4: Πηληϊάδεω
# Word 5: Ἀχιλῆος
# Word 6: οὐλομένην
# Word 7: ,
# Word 8: ἣ
# Word 9: μυρίʼ
# Word 10: Ἀχαιοῖς
# Word 11: ἄλγεʼ
# Word 12: ἔθηκε
# Word 13: ,
# Word 14: πολλὰς

# %%
# Tokens as plain strings

plaintext_tokens = G.tokens(iliad_1, as_text=True)

for i in range(1, 10):
    t = next(plaintext_tokens)
    print(f'{t} ({type(t).__name__})')
# Out:
# μῆνιν (str)
# ἄειδε (str)
# θεὰ (str)
# Πηληϊάδεω (str)
# Ἀχιλῆος (str)
# οὐλομένην (str)
# , (str)
# ἣ (str)
# μυρίʼ (str)

# %%
# Lines (citation units from the Tesserae format)

iliad_lines = G.lines(iliad_1)

for i in range(1, 9):
    line = next(iliad_lines)
    print(f'{line._.citation}: {line}')
# Out:
# <hom. il. 1.1>: μῆνιν ἄειδε θεὰ Πηληϊάδεω Ἀχιλῆος οὐλομένην
# <hom. il. 1.2>: οὐλομένην, ἣ μυρίʼ Ἀχαιοῖς ἄλγεʼ ἔθηκε, πολλὰς δʼ ἰφθίμους
# <hom. il. 1.3>: ψυχὰς Ἄϊδι προί̈αψεν ἡρώων, αὐτοὺς δὲ ἑλώρια τεῦχε
# <hom. il. 1.4>: τεῦχε κύνεσσιν οἰωνοῖσί τε πᾶσι, Διὸς δʼ ἐτελείετο
# <hom. il. 1.5>: βουλή, ἐξ οὗ δὴ τὰ πρῶτα διαστήτην ἐρίσαντε Ἀτρεί̈δης
# <hom. il. 1.6>: Ἀτρεί̈δης τε ἄναξ ἀνδρῶν καὶ δῖος Ἀχιλλεύς. τίς τʼ ἄρ
# <hom. il. 1.7>: σφωε θεῶν ἔριδι ξυνέηκε μάχεσθαι; Λητοῦς καὶ Διὸς υἱός
# <hom. il. 1.8>: υἱός: ὃ γὰρ βασιλῆϊ χολωθεὶς νοῦσον ἀνὰ στρατὸν ὄρσε κακήν

# %%
# Doc stats

iliad_doc = next(G.docs(iliad_1))

print(f'Stats for {iliad_1}:')
print(f'  Sentences: {len(list(iliad_doc.sents))}')
print(f'  Tokens: {len(iliad_doc)}')
print(f'  Citation lines: {len(iliad_doc.spans.get("lines", []))}')
# Out:
# Stats for homer.iliad.part.1.tess:
#   Sentences: 349
#   Tokens: 5140
#   Citation lines: 498

# %% [markdown]
# ## Search
#
# Fast regex-based search across the corpus. No NLP model required.

# %%
from itertools import islice

# %%
# search() - find lines matching a regex
# Search for Achilles across all Homer

homer_files = G.fileids(match='homer')

results = G.search(r'Ἀχιλ', fileids=homer_files)
for fileid, citation, text, matches in islice(results, 10):
    print(f"{citation}: found {matches}")
    print(f"  → {text[:70]}...")
    print()
# Out:
# <hom. il. 1.1>: found ['Ἀχιλ']
#   → μῆνιν ἄειδε θεὰ Πηληϊάδεω Ἀχιλῆος...
#
# <hom. il. 1.7>: found ['Ἀχιλ']
#   → Ἀτρεί̈δης τε ἄναξ ἀνδρῶν καὶ δῖος Ἀχιλλεύς....
#
# <hom. il. 1.54>: found ['Ἀχιλ']
#   → τῇ δεκάτῃ δʼ ἀγορὴν δὲ καλέσσατο λαὸν Ἀχιλλεύς:...
#
# <hom. il. 1.58>: found ['Ἀχιλ']
#   → τοῖσι δʼ ἀνιστάμενος μετέφη πόδας ὠκὺς Ἀχιλλεύς:...
#
# <hom. il. 1.74>: found ['Ἀχιλ']
#   → ὦ Ἀχιλεῦ κέλεαί με Διὶ̈ φίλε μυθήσασθαι...
#
# <hom. il. 1.84>: found ['Ἀχιλ']
#   → τὸν δʼ ἀπαμειβόμενος προσέφη πόδας ὠκὺς Ἀχιλλεύς:...
#
# <hom. il. 1.121>: found ['Ἀχιλ']
#   → τὸν δʼ ἠμείβετʼ ἔπειτα ποδάρκης δῖος Ἀχιλλεύς:...
#
# <hom. il. 1.131>: found ['Ἀχιλ']
#   → μὴ δʼ οὕτως ἀγαθός περ ἐὼν θεοείκελʼ Ἀχιλλεῦ...
#
# <hom. il. 1.148>: found ['Ἀχιλ']
#   → τὸν δʼ ἄρʼ ὑπόδρα ἰδὼν προσέφη πόδας ὠκὺς Ἀχιλλεύς:...
#
# <hom. il. 1.199>: found ['Ἀχιλ']
#   → θάμβησεν δʼ Ἀχιλεύς, μετὰ δʼ ἐτράπετʼ, αὐτίκα δʼ ἔγνω...

# %%
# find_lines() - find citation lines with specific words/patterns

# Search for Zeus across corpus
for fileid, citation, text in islice(G.find_lines(pattern=r'Ζεὺς'), 10):
    print(f"{citation}: {text[:70]}...")
# Out:
# <Ach. Tat.  2.1.2>: Εἴ τις τὰς καμπὰς τῆς ᾠδῆς περιελὼν ψιλὸν ἔλεγεν ἁρμονίας τὸν λόγον, ο...
# <Ach. Tat.  2.15.4>: Βαδίζει δὲ ταῦρος ὑψαυχενῶν καὶ ὥσπερ ἐπιδεικνύμενος ὅτι τῶν ἄλλων βοῶ...
# <Ach. Tat.  2.37.2>: Ἠράσθη μειρακίου Φρυγός, ἀνήγαγεν εἰς οὐρανὸν τὸν Φρύγα: τὸ δὲ κάλλος ...
# <Ach. Tat.  2.37.4>: Σεμέλην δὲ εἰς οὐρανὸν ἀνήγαγεν οὐκ ὄρνις ὠμηστής, ἀλλὰ πῦρ: καὶ μὴ θα...
# <Ael. NA 6.50>: Κλεάνθην τὸν Ἄσσιον κατηνάγκασε καὶ ἄκοντα εἶξαι καὶ ἀποστῆναι τοῖς ζῴ...
# <Ael. NA 12.30>: χειροήθεις δὲ ἰχθῦς καὶ ὑπακούοντες τῇ κλήσει καὶ τροφὰς ἀσμένως δεχόμ...
# <Ael. VH 12.25>: χιλίους μὲν μαγείρους, τοσούτους δὲ ὀρνιθευτάς, καὶ ἁλιεῖς χιλίους. Ὤν...
# <Ael. VH 12.51>: Μενεκράτης ὁ ἰατρὸς ἐς τοσοῦτον προῆλθε τύφου, ὥστε ἑαυτὸν ὀνομάζειν Δ...
# <Ael. Ar. Orat. 7 1.2>: καὶ πράττειν καὶ λέγειν. ὅμως δὲ, οὐ γὰρ ἐκλειπτέον οὐδὲν εὐκταῖον, φα...
# <Ael. Ar. Orat. 7 1.6>: ἀθροίζοντες ἀλλήλους πόλεις ᾤκιζον, τὰς ἀκροπόλεις ἐξεῖλον Διὶ, πρός τ...

# %%
# find_lines() with specific forms

forms = ["μῆνιν", "μῆνις", "μήνιος", "μήνιδος"]
for fileid, citation, text in G.find_lines(forms=forms, fileids=homer_files):
    print(f"{citation}: {text[:70]}...")
# Out:
# <hom. il. 1.1>: μῆνιν ἄειδε θεὰ Πηληϊάδεω Ἀχιλῆος...
# <hom. il. 1.75>: μῆνιν Ἀπόλλωνος ἑκατηβελέταο ἄνακτος:...
# <hom. il. 5.34>: νῶϊ δὲ χαζώμεσθα, Διὸς δʼ ἀλεώμεθα μῆνιν;...
# <hom. il. 5.178>: ἱρῶν μηνίσας: χαλεπὴ δὲ θεοῦ ἔπι μῆνις....
# <hom. il. 5.444>: μῆνιν ἀλευάμενος ἑκατηβόλου Ἀπόλλωνος....
# <hom. il. 9.517>: οὐκ ἂν ἔγωγέ σε μῆνιν ἀπορρίψαντα κελοίμην...
# <hom. il. 13.624>: Ζηνὸς ἐριβρεμέτεω χαλεπὴν ἐδείσατε μῆνιν...
# <hom. il. 15.122>: πὰρ Διὸς ἀθανάτοισι χόλος καὶ μῆνις ἐτύχθη,...
# <hom. il. 16.711>: μῆνιν ἀλευάμενος ἑκατηβόλου Ἀπόλλωνος....
# <hom. il. 19.35>: μῆνιν ἀποειπὼν Ἀγαμέμνονι ποιμένι λαῶν...
# <hom. il. 19.75>: μῆνιν ἀπειπόντος μεγαθύμου Πηλεί̈ωνος....
# <hom. il. 21.523>: ἄστεος αἰθομένοιο, θεῶν δέ ἑ μῆνις ἀνῆκε,...
# <hom.od 2.66>: οἳ περιναιετάουσι: θεῶν δʼ ὑποδείσατε μῆνιν,...
# <hom.od 3.135>: μήνιος ἐξ ὀλοῆς γλαυκώπιδος ὀβριμοπάτρης....
# <hom.od 5.146>: “οὕτω νῦν ἀπόπεμπε, Διὸς δʼ ἐποπίζεο μῆνιν,...
# <hom.od 14.283>: ἀλλʼ ἀπὸ κεῖνος ἔρυκε, Διὸς δʼ ὠπίζετο μῆνιν...

# %%
# find_sents() - find sentences containing a pattern

for hit in islice(G.find_sents(pattern=r'Ἀχιλ', fileids=homer_files), 5):
    print(f"{hit['citation']}: {hit['sentence'][:80]}...")
    print(f"  Matched: {hit['matches']}")
    print()
# Out:
# <hom. il. 1.1>: μῆνιν ἄειδε θεὰ Πηληϊάδεω Ἀχιλῆος οὐλομένην, ἣ μυρίʼ Ἀχαιοῖς ἄλγεʼ ἔθηκε, πολλὰς...
#   Matched: ['Ἀχιλ', 'Ἀχιλ']
#
# <hom. il. 1.43>: ἐννῆμαρ μὲν ἀνὰ στρατὸν ᾤχετο κῆλα θεοῖο, τῇ δεκάτῃ δʼ ἀγορὴν δὲ καλέσσατο λαὸν ...
#   Matched: ['Ἀχιλ']
#
# <hom. il. 1.46>: οἳ δʼ ἐπεὶ οὖν ἤγερθεν ὁμηγερέες τε γένοντο, τοῖσι δʼ ἀνιστάμενος μετέφη πόδας ὠ...
#   Matched: ['Ἀχιλ']
#
# <hom. il. 1.61>: ὦ Ἀχιλεῦ κέλεαί με Διὶ̈ φίλε μυθήσασθαι μῆνιν Ἀπόλλωνος ἑκατηβελέταο ἄνακτος:...
#   Matched: ['Ἀχιλ']
#
# <hom. il. 1.68>: τὸν δʼ ἀπαμειβόμενος προσέφη πόδας ὠκὺς Ἀχιλλεύς:...
#   Matched: ['Ἀχιλ']

# %%
# find_sents() with context

for hit in islice(G.find_sents(pattern=r'μῆνιν', fileids=homer_files, context=True), 3):
    if hit.get('prev_sent'):
        print(f"  [prev] {hit['prev_sent'][:60]}...")
    print(f"  >>> {hit['sentence'][:80]}...")
    if hit.get('next_sent'):
        print(f"  [next] {hit['next_sent'][:60]}...")
    print(f"  -- {hit['citation']}")
    print()
# Out:
#   >>> μῆνιν ἄειδε θεὰ Πηληϊάδεω Ἀχιλῆος οὐλομένην, ἣ μυρίʼ Ἀχαιοῖς ἄλγεʼ ἔθηκε, πολλὰς...
#   [next] τίς τʼ ἄρ σφωε θεῶν ἔριδι ξυνέηκε μάχεσθαι;...
#   -- <hom. il. 1.1>
#
#   [prev] ὅ σφιν ἐὺ φρονέων ἀγορήσατο καὶ μετέειπεν:...
#   >>> ὦ Ἀχιλεῦ κέλεαί με Διὶ̈ φίλε μυθήσασθαι μῆνιν Ἀπόλλωνος ἑκατηβελέταο ἄνακτος:...
#   [next] τοὶ γὰρ ἐγὼν ἐρέω:...
#   -- <hom. il. 1.61>
#   [prev] ἀτὰρ γλαυκῶπις Ἀθήνη χειρὸς ἑλοῦςʼ ἐπέεσσι προσηύδα θοῦρον Ἄ...
#   >>> Ἆρες Ἄρες βροτολοιγὲ μιαιφόνε τειχεσιπλῆτα οὐκ ἂν δὴ Τρῶας μὲν ἐάσαιμεν καὶ Ἀχαι...
#   [next] ὣς εἰποῦσα μάχης ἐξήγαγε θοῦρον Ἄρηα:...
#   -- <hom. il. 5.25>

# %% [markdown]
# ## KWIC (Keyword in Context)

# %%
# Basic KWIC search
for hit in G.kwic("θεὰ", fileids=homer_files, window=5, limit=10):
    print(f"{hit['left']:>50s} [{hit['match']}] {hit['right']:<50s}")
    print(f"{'':>50s}  {hit['citation']}")
    print()
# Out:
#                                        μῆνιν ἄειδε [θεὰ] Πηληϊάδεω Ἀχιλῆος οὐλομένην , ἣ
#                                                     <hom. il. 1.1>
#
#                              τῷ γὰρ ἐπὶ φρεσὶ θῆκε [θεὰ] λευκώλενος Ἥρη : κήδετο γὰρ
#                                                     <hom. il. 1.45>
#
#                            οὐρανόθεν : πρὸ γὰρ ἧκε [θεὰ] λευκώλενος Ἥρη ἄμφω ὁμῶς θυμῷ
#                                                     <hom. il. 1.160>
#
#                            . τὸν δʼ αὖτε προσέειπε [θεὰ] γλαυκῶπις Ἀθήνη : ἦλθον ἐγὼ
#                                                     <hom. il. 1.168>
#
#                                    : πρὸ δέ μʼ ἧκε [θεὰ] λευκώλενος Ἥρη ἄμφω ὁμῶς θυμῷ
#                                                     <hom. il. 1.170>
#
#                            : χρὴ μὲν σφωί̈τερόν γε [θεὰ] ἔπος εἰρύσσασθαι καὶ μάλα περ
#                                                     <hom. il. 1.176>
#
#                             εἰ δὲ σὺ καρτερός ἐσσι [θεὰ] δέ σε γείνατο μήτηρ ,
#                                                     <hom. il. 1.229>
#
#                             ἀλλὰ σὺ τόν γʼ ἐλθοῦσα [θεὰ] ὑπελύσαο δεσμῶν , ὦχʼ ἑκατόγχειρον
#                                                     <hom. il. 1.327>
#
#                              ὣς φάτο , μείδησεν δὲ [θεὰ] λευκώλενος Ἥρη , μειδήσασα δὲ
#                                                     <hom. il. 1.486>
#
#                          χαλκοχιτώνων : ἠὼς μέν ῥα [θεὰ] προσεβήσετο μακρὸν Ὄλυμπον Ζηνὶ φόως
#                                                     <hom. il. 2.39>

# %%
# KWIC for a character name
for hit in G.kwic("Ἕκτωρ", fileids=homer_files, window=5, limit=10):
    print(f"{hit['left']:>50s} [{hit['match']}] {hit['right']:<50s}")
    print(f"{'':>50s}  {hit['citation']}")
    print()
# Out:
#                              πολιήτας . ὣς ἔφαθʼ , [Ἕκτωρ] δʼ οὔ τι θεᾶς ἔπος
#                                                     <hom. il. 2.659>
#
#              Τρωσὶ μὲν ἡγεμόνευε μέγας κορυθαίολος [Ἕκτωρ] Πριαμίδης : ἅμα τῷ γε
#                                                     <hom. il. 2.667>
#
#                       Ἀλέξανδρος θεοειδής . τὸν δʼ [Ἕκτωρ] νείκεσσεν ἰδὼν αἰσχροῖς ἐπέεσσιν :
#                                                     <hom. il. 3.31>
#
#                          καλλιγύναικα . ὣς ἔφαθʼ , [Ἕκτωρ] δʼ αὖτʼ ἐχάρη μέγα μῦθον
#                                                     <hom. il. 3.62>
#
#                     γάρ τι ἔπος ἐρέειν κορυθαίολος [Ἕκτωρ] . ὣς ἔφαθʼ , οἳ
#                                                     <hom. il. 3.68>
#
#                       ἄνεῴ τʼ ἐγένοντο ἐσσυμένως : [Ἕκτωρ] δὲ μετʼ ἀμφοτέροισιν ἔειπε :
#                                                     <hom. il. 3.70>
#
#                               δʼ ἦν ἀμφὶς ἄρουρα : [Ἕκτωρ] δὲ προτὶ ἄστυ δύω κήρυκας
#                                                     <hom. il. 3.95>
#
#                    ἄψορροι προτὶ Ἴλιον ἀπονέοντο : [Ἕκτωρ] δὲ Πριάμοιο πάϊς καὶ δῖος
#                                                     <hom. il. 3.257>
#
#                      , πάλλεν δὲ μέγας κορυθαίολος [Ἕκτωρ] ἂψ ὁρόων : Πάριος δὲ
#                                                     <hom. il. 3.265>
#
#                       ὑπό τε πρόμαχοι καὶ φαίδιμος [Ἕκτωρ] : Ἀργεῖοι δὲ μέγα ἴαχον
#                                                     <hom. il. 4.416>

# %% [markdown]
# ## N-grams

# %%
# Bigrams from Iliad Book 1

bigrams = list(islice(G.ngrams(n=2, fileids=iliad_1), 20))
print("First 20 bigrams from Iliad 1:")
pprint(bigrams)
# Out:
# First 20 bigrams from Iliad 1:
# ['μῆνιν ἄειδε',
#  'ἄειδε θεὰ',
#  'θεὰ Πηληϊάδεω',
#  'Πηληϊάδεω Ἀχιλῆος',
#  'Ἀχιλῆος οὐλομένην',
#  'ἣ μυρίʼ',
#  'μυρίʼ Ἀχαιοῖς',
#  'Ἀχαιοῖς ἄλγεʼ',
#  'ἄλγεʼ ἔθηκε',
#  'πολλὰς δʼ',
#  'δʼ ἰφθίμους',
#  'ἰφθίμους ψυχὰς',
#  'ψυχὰς Ἄϊδι',
#  'Ἄϊδι προί̈αψεν',
#  'προί̈αψεν ἡρώων',
#  'αὐτοὺς δὲ',
#  'δὲ ἑλώρια',
#  'ἑλώρια τεῦχε',
#  'τεῦχε κύνεσσιν',
#  'κύνεσσιν οἰωνοῖσί']

# %%
# Trigrams
trigrams = list(islice(G.ngrams(n=3, fileids=iliad_1), 10))
print("First 10 trigrams:")
pprint(trigrams)
# Out:
# First 10 trigrams:
# ['μῆνιν ἄειδε θεὰ',
#  'ἄειδε θεὰ Πηληϊάδεω',
#  'θεὰ Πηληϊάδεω Ἀχιλῆος',
#  'Πηληϊάδεω Ἀχιλῆος οὐλομένην',
#  'ἣ μυρίʼ Ἀχαιοῖς',
#  'μυρίʼ Ἀχαιοῖς ἄλγεʼ',
#  'Ἀχαιοῖς ἄλγεʼ ἔθηκε',
#  'πολλὰς δʼ ἰφθίμους',
#  'δʼ ἰφθίμους ψυχὰς',
#  'ἰφθίμους ψυχὰς Ἄϊδι']

# %%
# Bigram frequency analysis
from collections import Counter

bigram_counts = Counter(G.ngrams(n=2, fileids=homer_files))
print("Most common bigrams in Homer:")
for bigram, count in bigram_counts.most_common(15):
    print(f"  {bigram}: {count}")
# Out:
# Most common bigrams in Homer:
#   τε καὶ: 513
#   τὸν δʼ: 466
#   δʼ ἄρα: 328
#   δʼ ἄρʼ: 267
#   δέ οἱ: 250
#   οἳ δʼ: 195
#   ὃ δʼ: 190
#   οἱ δʼ: 156
#   δʼ ἐν: 141
#   δʼ αὖτε: 140
#   δὲ καὶ: 139
#   ὣς φάτο: 138
#   ὣς ἔφατʼ: 136
#   τὴν δʼ: 130
#   δέ μιν: 129

# %%
# Skipgrams - word pairs with gaps
# n=2 (pairs), k=1 (allow 1 word gap)

skipgrams = list(islice(G.skipgrams(n=2, k=1, fileids=iliad_1), 15))
print("First 15 skipgrams (bigrams with 1 skip):")
pprint(skipgrams)
# Out:
# First 15 skipgrams (bigrams with 1 skip):
# ['μῆνιν ἄειδε',
#  'μῆνιν θεὰ',
#  'ἄειδε θεὰ',
#  'ἄειδε Πηληϊάδεω',
#  'θεὰ Πηληϊάδεω',
#  'θεὰ Ἀχιλῆος',
#  'Πηληϊάδεω Ἀχιλῆος',
#  'Πηληϊάδεω οὐλομένην',
#  'Ἀχιλῆος οὐλομένην',
#  'Ἀχιλῆος ἣ',
#  'οὐλομένην ἣ',
#  'οὐλομένην μυρίʼ',
#  'ἣ μυρίʼ',
#  'ἣ Ἀχαιοῖς',
#  'μυρίʼ Ἀχαιοῖς']

# %% [markdown]
# ## Word counting

# %%
# Simple word counting from raw text (fastest method)

word_counts = Counter()

for citation, text in G.texts_by_line(fileids=homer_files):
    words = text.split()
    word_counts.update(words)

print(f"Total word tokens: {sum(word_counts.values())}")
print(f"Unique word types: {len(word_counts)}")
print("\nMost common words in Homer:")
for word, count in word_counts.most_common(20):
    print(f"  {word:20s} {count:>6d}")
# Out:
# Total word tokens: 199045
# Unique word types: 40852
#
# Most common words in Homer:
#   δʼ                     6485
#   καὶ                    4797
#   δὲ                     3188
#   τε                     2365
#   μὲν                    1634
#   ἐν                     1416
#   δέ                     1238
#   οἱ                     1125
#   τʼ                     1098
#   ὣς                     1096
#   γὰρ                     965
#   ἀλλʼ                    930
#   τὸν                     899
#   ἐπὶ                     829
#   τοι                     752
#   αὐτὰρ                   752
#   δὴ                      737
#   μοι                     724
#   μιν                     641
#   ἐπεὶ                    611

# %%
# Character mention counts

characters = {
    "Achilles": r"Ἀχιλ",
    "Hector": r"Ἕκτ",
    "Odysseus": r"Ὀδυσ",
    "Zeus": r"Ζε[υύ]",
    "Athena": r"Ἀθην",
    "Apollo": r"Ἀπόλλ",
    "Agamemnon": r"Ἀγαμέμν",
    "Patroclus": r"Πατρόκλ",
}

print("Character mentions (lines) in Homer:")
for name, pattern in characters.items():
    count = len(list(G.search(pattern, fileids=homer_files)))
    print(f"  {name:15s} {count:>4d} lines")
# Out:
# Character mentions (lines) in Homer:
#   Achilles         383 lines
#   Hector           452 lines
#   Odysseus         724 lines
#   Zeus              94 lines
#   Athena            97 lines
#   Apollo           149 lines
#   Agamemnon        171 lines
#   Patroclus         68 lines

# %% [markdown]
# ## Export results

# %%
# Export search results to TSV

results = G.find_sents(pattern=r'Ἀχιλ', fileids=homer_files)
export = G.export_search_results(results, format="tsv")

print("TSV export (first 500 chars):")
print(export[:500])
# Out:
# TSV export (first 500 chars):
# fileid	citation	matches	sentence
# homer.iliad.part.1.tess	<hom. il. 1.1>	Ἀχιλ;Ἀχιλ	μῆνιν ἄειδε θεὰ Πηληϊάδεω Ἀχιλῆος οὐλομένην, ἣ μυρίʼ Ἀχαιοῖς ἄλγεʼ ἔθηκε, πολλὰς δʼ ἰφθίμους ψυχὰς Ἄϊδι προί̈αψεν ἡρώων, αὐτοὺς δὲ ἑλώρια τεῦχε κύνεσσιν οἰωνοῖσί τε πᾶσι, Διὸς δʼ ἐτελείετο βουλή, ἐξ οὗ δὴ τὰ πρῶτα διαστήτην ἐρίσαντε Ἀτρεί̈δης τε ἄναξ ἀνδρῶν καὶ δῖος Ἀχιλλεύς.
# homer.iliad.part.1.tess	<hom. il. 1.43>	Ἀχιλ	ἐννῆμαρ μὲν ἀνὰ στρατὸν ᾤχετο κῆλα θεοῖο, τῇ δεκάτῃ δʼ ἀγορὴν δὲ καλέσσατο λαὸν Ἀχιλλεύς:
# homer.

# %%
# Export as JSONL

results = G.find_sents(forms=["μῆνιν"], fileids=homer_files)
export = G.export_search_results(results, format="jsonl")
print(export)
# Out:
# {"fileid": "homer.iliad.part.1.tess", "citation": "<hom. il. 1.1>", "sentence": "μῆνιν ἄειδε θεὰ Πηληϊάδεω Ἀχιλῆος οὐλομένην, ἣ μυρίʼ Ἀχαιοῖς ἄλγεʼ ἔθηκε, πολλὰς δʼ ἰφθίμους ψυχὰς Ἄϊδι προί̈αψεν ἡρώων, αὐτοὺς δὲ ἑλώρια τεῦχε κύνεσσιν οἰωνοῖσί τε πᾶσι, Διὸς δʼ ἐτελείετο βουλή, ἐξ οὗ δὴ τὰ πρῶτα διαστήτην ἐρίσαντε Ἀτρεί̈δης τε ἄναξ ἀνδρῶν καὶ δῖος Ἀχιλλεύς.", "matches": ["μῆνιν"]}
# {"fileid": "homer.iliad.part.1.tess", "citation": "<hom. il. 1.61>", "sentence": "ὦ Ἀχιλεῦ κέλεαί με Διὶ̈ φίλε μυθήσασθαι μῆνιν Ἀπόλλωνος ἑκατηβελέταο ἄνακτος:", "matches": ["μῆνιν"]}
# {"fileid": "homer.iliad.part.5.tess", "citation": "<hom. il. 5.25>", "sentence": "Ἆρες Ἄρες βροτολοιγὲ μιαιφόνε τειχεσιπλῆτα οὐκ ἂν δὴ Τρῶας μὲν ἐάσαιμεν καὶ Ἀχαιοὺς μάρνασθʼ, ὁπποτέροισι πατὴρ Ζεὺς κῦδος ὀρέξῃ, νῶϊ δὲ χαζώμεσθα, Διὸς δʼ ἀλεώμεθα μῆνιν;", "matches": ["μῆνιν"]}
# {"fileid": "homer.iliad.part.5.tess", "citation": "<hom. il. 5.360>", "sentence": "ὣς φάτο, Τυδεί̈δης δʼ ἀνεχάζετο τυτθὸν ὀπίσσω μῆνιν ἀλευάμενος ἑκατηβόλου Ἀπόλλωνος.", "matches": ["μῆνιν"]}
# {"fileid": "homer.iliad.part.9.tess", "citation": "<hom. il. 9.418>", "sentence": "εἰ μὲν γὰρ μὴ δῶρα φέροι τὰ δʼ ὄπισθʼ ὀνομάζοι Ἀτρεί̈δης, ἀλλʼ αἰὲν ἐπιζαφελῶς χαλεπαίνοι, οὐκ ἂν ἔγωγέ σε μῆνιν ἀπορρίψαντα κελοίμην Ἀργείοισιν ἀμυνέμεναι χατέουσί περ ἔμπης:", "matches": ["μῆνιν"]}
# {"fileid": "homer.iliad.part.13.tess", "citation": "<hom. il. 13.508>", "sentence": "λείψετέ θην οὕτω γε νέας Δαναῶν ταχυπώλων Τρῶες ὑπερφίαλοι δεινῆς ἀκόρητοι ἀϋτῆς, ἄλλης μὲν λώβης τε καὶ αἴσχεος οὐκ ἐπιδευεῖς ἣν ἐμὲ λωβήσασθε κακαὶ κύνες, οὐδέ τι θυμῷ Ζηνὸς ἐριβρεμέτεω χαλεπὴν ἐδείσατε μῆνιν ξεινίου, ὅς τέ ποτʼ ὔμμι διαφθέρσει πόλιν αἰπήν:", "matches": ["μῆνιν"]}
# {"fileid": "homer.iliad.part.16.tess", "citation": "<hom. il. 16.584>", "sentence": "ὣς φάτο, Πάτροκλος δʼ ἀνεχάζετο πολλὸν ὀπίσσω μῆνιν ἀλευάμενος ἑκατηβόλου Ἀπόλλωνος.", "matches": ["μῆνιν"]}
# {"fileid": "homer.iliad.part.19.tess", "citation": "<hom. il. 19.27>", "sentence": "ἀλλὰ σύ γʼ εἰς ἀγορὴν καλέσας ἥρωας Ἀχαιοὺς μῆνιν ἀποειπὼν Ἀγαμέμνονι ποιμένι λαῶν αἶψα μάλʼ ἐς πόλεμον θωρήσσεο, δύσεο δʼ ἀλκήν.", "matches": ["μῆνιν"]}
# {"fileid": "homer.iliad.part.19.tess", "citation": "<hom. il. 19.60>", "sentence": "ὣς ἔφαθʼ, οἳ δʼ ἐχάρησαν ἐϋκνήμιδες Ἀχαιοὶ μῆνιν ἀπειπόντος μεγαθύμου Πηλεί̈ωνος.", "matches": ["μῆνιν"]}
# {"fileid": "homer.odyssey.part.2.tess", "citation": "<hom.od 2.53>", "sentence": "θεῶν δʼ ὑποδείσατε μῆνιν, μή τι μεταστρέψωσιν ἀγασσάμενοι κακὰ ἔργα.", "matches": ["μῆνιν"]}
# {"fileid": "homer.odyssey.part.5.tess", "citation": "<hom.od 5.119>", "sentence": "οὕτω νῦν ἀπόπεμπε, Διὸς δʼ ἐποπίζεο μῆνιν, μή πώς τοι μετόπισθε κοτεσσάμενος χαλεπήνῃ.”", "matches": ["μῆνιν"]}
# {"fileid": "homer.odyssey.part.14.tess", "citation": "<hom.od 14.229>", "sentence": "ἦ μέν μοι μάλα πολλοὶ ἐπήϊσσον μελίῃσιν, ἱέμενοι κτεῖναι—δὴ γὰρ κεχολώατο λίην— ἀλλʼ ἀπὸ κεῖνος ἔρυκε, Διὸς δʼ ὠπίζετο μῆνιν ξεινίου, ὅς τε μάλιστα νεμεσσᾶται κακὰ ἔργα. “", "matches": ["μῆνιν"]}

# %% [markdown]
# ## With OdyCy NLP model (BASIC/FULL annotation)
#
# The following cells require the OdyCy model for lemmatization and POS tagging.
#
# ```bash
# pip install https://huggingface.co/chcaa/grc_odycy_joint_sm/resolve/main/grc_odycy_joint_sm-any-py3-none-any.whl
# ```

# %%
# Reload with BASIC annotation level for lemmatization + POS
G_nlp = GreekTesseraeReader(annotation_level=AnnotationLevel.BASIC)

# %%
# POS-tagged sentences

iliad_sents = G_nlp.sents(iliad_1)

for i in range(1, 4):
    sent = next(iliad_sents)
    pos_sent = [f"{t.text}/{t.pos_}" for t in sent]
    print(f'POS Sent {i}: {" ".join(pos_sent)}')
    print()
# Out:
# /Volumes/fiona/work/code/diy/latincy-v3/latincy-readers/.venv/lib/python3.11/site-packages/spacy/util.py:969: UserWarning: [W095] Model 'grc_odycy_joint_sm' (0.7.0) was trained with spaCy v3.7.4 and may not be 100% compatible with the current version (3.8.11). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# POS Sent 1: μῆνιν/NOUN ἄειδε/VERB θεὰ/NOUN Πηληϊάδεω/NOUN Ἀχιλῆος/NOUN οὐλομένην/ADJ ,/PUNCT ἣ/DET μυρίʼ/ADJ Ἀχαιοῖς/ADJ ἄλγεʼ/VERB ἔθηκε/VERB ,/PUNCT πολλὰς/ADJ δʼ/ADJ ἰφθίμους/ADJ ψυχὰς/NOUN Ἄϊδι/NOUN προί̈αψεν/VERB ἡρώων/NOUN ,/PUNCT αὐτοὺς/PRON δὲ/CCONJ ἑλώρια/ADJ τεῦχε/NOUN κύνεσσιν/NOUN οἰωνοῖσί/ADJ τε/PART πᾶσι/ADJ ,/PUNCT Διὸς/NOUN δʼ/ADJ ἐτελείετο/VERB βουλή/NOUN ,/PUNCT ἐξ/ADP οὗ/PRON δὴ/PART τὰ/DET πρῶτα/ADJ διαστήτην/VERB ἐρίσαντε/VERB Ἀτρεί̈δης/NOUN τε/PART ἄναξ/NOUN ἀνδρῶν/NOUN καὶ/CCONJ δῖος/ADJ Ἀχιλλεύς/NOUN ./PUNCT
#
# POS Sent 2: τίς/PRON τʼ/PRON ἄρ/PART σφωε/PRON θεῶν/NOUN ἔριδι/NOUN ξυνέηκε/VERB μάχεσθαι/VERB ;/PUNCT Λητοῦς/NOUN καὶ/CCONJ Διὸς/NOUN υἱός/NOUN :/NOUN ὃ/PRON γὰρ/PART βασιλῆϊ/NOUN χολωθεὶς/VERB νοῦσον/NOUN ἀνὰ/ADP στρατὸν/NOUN ὄρσε/VERB κακήν/ADJ ,/PUNCT ὀλέκοντο/VERB δὲ/PART λαοί/NOUN ,/PUNCT οὕνεκα/SCONJ τὸν/DET Χρύσην/NOUN ἠτίμασεν/VERB ἀρητῆρα/NOUN Ἀτρεί̈δης/NOUN :/ADJ ὃ/PRON γὰρ/ADV ἦλθε/VERB θοὰς/ADJ ἐπὶ/ADP νῆας/NOUN Ἀχαιῶν/ADJ λυσόμενός/NOUN τε/PART θύγατρα/NOUN φέρων/VERB τʼ/ADJ ἀπερείσιʼ/ADJ ἄποινα/NOUN ,/PUNCT στέμματʼ/ADJ ἔχων/VERB ἐν/ADP χερσὶν/NOUN ἑκηβόλου/ADJ Ἀπόλλωνος/NOUN χρυσέῳ/ADJ ἀνὰ/ADP σκήπτρῳ/NOUN ,/PUNCT καὶ/CCONJ λίσσετο/VERB πάντας/ADJ Ἀχαιούς/NOUN ,/PUNCT Ἀτρεί̈δα/ADJ δὲ/PART μάλιστα/ADV δύω/NUM ,/PUNCT κοσμήτορε/ADJ λαῶν/NOUN :/NOUN Ἀτρεί̈δαι/ADJ τε/PART καὶ/CCONJ ἄλλοι/ADJ ἐϋκνήμιδες/ADJ Ἀχαιοί/ADJ ,/PUNCT ὑμῖν/PRON μὲν/PART θεοὶ/NOUN δοῖεν/VERB Ὀλύμπια/ADJ δώματʼ/ADJ ἔχοντες/VERB ἐκπέρσαι/VERB Πριάμοιο/NOUN πόλιν/NOUN ,/PUNCT εὖ/ADV δʼ/ADJ οἴκαδʼ/NOUN ἱκέσθαι/VERB :/NOUN παῖδα/NOUN δʼ/ADV ἐμοὶ/PRON λύσαιτε/AUX φίλην/ADJ ,/PUNCT τὰ/DET δʼ/ADJ ἄποινα/NOUN δέχεσθαι/VERB ,/PUNCT ἁζόμενοι/VERB Διὸς/NOUN υἱὸν/NOUN ἑκηβόλον/ADJ Ἀπόλλωνα/NOUN ./PUNCT
#
# POS Sent 3: ἔνθʼ/VERB ἄλλοι/ADJ μὲν/ADV πάντες/ADJ ἐπευφήμησαν/VERB Ἀχαιοὶ/ADJ αἰδεῖσθαί/VERB θʼ/NOUN ἱερῆα/NOUN καὶ/CCONJ ἀγλαὰ/ADJ δέχθαι/VERB ἄποινα/NOUN :/NOUN ἀλλʼ/VERB οὐκ/ADV Ἀτρεί̈δῃ/ADJ Ἀγαμέμνονι/NOUN ἥνδανε/VERB θυμῷ/NOUN ,/PUNCT ἀλλὰ/CCONJ κακῶς/ADV ἀφίει/VERB ,/PUNCT κρατερὸν/ADJ δʼ/ADJ ἐπὶ/ADP μῦθον/NOUN ἔτελλε/VERB :/NOUN μή/CCONJ σε/PRON γέρον/NOUN κοίλῃσιν/ADJ ἐγὼ/PRON παρὰ/ADP νηυσὶ/NOUN κιχείω/VERB ἢ/CCONJ νῦν/ADV δηθύνοντʼ/ADJ ἢ/CCONJ ὕστερον/ADJ αὖτις/ADV ἰόντα/VERB ,/PUNCT μή/CCONJ νύ/ADV τοι/PRON οὐ/ADV χραίσμῃ/VERB σκῆπτρον/NOUN καὶ/CCONJ στέμμα/NOUN θεοῖο/NOUN :/NOUN τὴν/DET δʼ/ADV ἐγὼ/PRON οὐ/ADV λύσω/VERB :/NOUN πρίν/SCONJ μιν/PRON καὶ/ADV γῆρας/NOUN ἔπεισιν/VERB ἡμετέρῳ/ADJ ἐνὶ/ADP οἴκῳ/NOUN ἐν/ADP Ἄργεϊ/NOUN τηλόθι/ADP πάτρης/NOUN ἱστὸν/NOUN ἐποιχομένην/VERB καὶ/CCONJ ἐμὸν/ADJ λέχος/NOUN ἀντιόωσαν/VERB :/NOUN ἀλλʼ/VERB ἴθι/VERB μή/CCONJ μʼ/ADV ἐρέθιζε/VERB σαώτερος/NOUN ὥς/ADV κε/PART νέηαι/VERB ./PUNCT

# %%
# Token linguistic attributes

iliad_sents = G_nlp.sents(iliad_1)
sent = next(iliad_sents)

for t in sent:
    print(f"  {t.text:20s} lemma={t.lemma_:20s} pos={t.pos_:8s} tag={t.tag_}")
# Out:
#   μῆνιν                lemma=μῆνις                pos=NOUN     tag=n-s---fa-
#   ἄειδε                lemma=ἀείδω                pos=VERB     tag=v3siia---
#   θεὰ                  lemma=θεά                  pos=NOUN     tag=n-s---fn-
#   Πηληϊάδεω            lemma=πηλείδης             pos=NOUN     tag=n-s---mg-
#   Ἀχιλῆος              lemma=ἀχιλλεύς             pos=NOUN     tag=n-s---mg-
#   οὐλομένην            lemma=οὐλόμενος            pos=ADJ      tag=a-s---fa-
#   ,                    lemma=,                    pos=PUNCT    tag=u--------
#   ἣ                    lemma=ὁ                    pos=DET      tag=p-s---fn-
#   μυρίʼ                lemma=μυρίʼς               pos=ADJ      tag=a-s---nn-
#   Ἀχαιοῖς              lemma=ἀχαιός               pos=ADJ      tag=a-p---md-
#   ἄλγεʼ                lemma=ἄλγεʼ                pos=VERB     tag=v-sapamn-
#   ἔθηκε                lemma=τίθημι               pos=VERB     tag=v3saia---
#   ,                    lemma=,                    pos=PUNCT    tag=u--------
#   πολλὰς               lemma=πολύς                pos=ADJ      tag=a-p---fa-
#   δʼ                   lemma=δʼ                   pos=ADJ      tag=a-s---na-
#   ἰφθίμους             lemma=ἴφθιμος              pos=ADJ      tag=a-p---fa-
#   ψυχὰς                lemma=ψυχή                 pos=NOUN     tag=n-p---fa-
#   Ἄϊδι                 lemma=ἀΐδης                pos=NOUN     tag=n-s---md-
#   προί̈αψεν            lemma=προί̈αψεν            pos=VERB     tag=v3saia---
#   ἡρώων                lemma=ἥρως                 pos=NOUN     tag=n-p---mg-
#   ,                    lemma=,                    pos=PUNCT    tag=u--------
#   αὐτοὺς               lemma=αὐτός                pos=PRON     tag=p-p---ma-
#   δὲ                   lemma=δέ                   pos=CCONJ    tag=c--------
#   ἑλώρια               lemma=ἑλώριος              pos=ADJ      tag=a-p---na-
#   τεῦχε                lemma=τεῦχε                pos=NOUN     tag=n-p---fa-
#   κύνεσσιν             lemma=κύων                 pos=NOUN     tag=n-p---md-
#   οἰωνοῖσί             lemma=οἰωνοῖσί             pos=ADJ      tag=a-p---md-
#   τε                   lemma=τε                   pos=PART     tag=g--------
#   πᾶσι                 lemma=πᾶς                  pos=ADJ      tag=a-p---md-
#   ,                    lemma=,                    pos=PUNCT    tag=u--------
#   Διὸς                 lemma=ζεύς                 pos=NOUN     tag=n-s---mg-
#   δʼ                   lemma=δʼ                   pos=ADJ      tag=a-s---na-
#   ἐτελείετο            lemma=ἐτελείω              pos=VERB     tag=v3siie---
#   βουλή                lemma=βουλή                pos=NOUN     tag=n-s---fn-
#   ,                    lemma=,                    pos=PUNCT    tag=u--------
#   ἐξ                   lemma=ἐκ                   pos=ADP      tag=r--------
#   οὗ                   lemma=ὅς                   pos=PRON     tag=p-s---ng-
#   δὴ                   lemma=δή                   pos=PART     tag=g--------
#   τὰ                   lemma=ὁ                    pos=DET      tag=l-p---na-
#   πρῶτα                lemma=πρῶτος               pos=ADJ      tag=Mo
#   διαστήτην            lemma=διασταίνω            pos=VERB     tag=v3daia---
#   ἐρίσαντε             lemma=ἐρίζω                pos=VERB     tag=v-dapamn-
#   Ἀτρεί̈δης            lemma=Ἀτρεί̈δης            pos=NOUN     tag=n-s---mn-
#   τε                   lemma=τε                   pos=PART     tag=g--------
#   ἄναξ                 lemma=ἄναξ                 pos=NOUN     tag=n-s---mn-
#   ἀνδρῶν               lemma=ἀνήρ                 pos=NOUN     tag=n-p---mg-
#   καὶ                  lemma=καί                  pos=CCONJ    tag=c--------
#   δῖος                 lemma=δῖος                 pos=ADJ      tag=a-s---mn-
#   Ἀχιλλεύς             lemma=ἀχιλλεύς             pos=NOUN     tag=n-s---mn-
#   .                    lemma=.                    pos=PUNCT    tag=u--------

# %%
# Concordance by lemma

homer_files = G_nlp.fileids(match='homer')
conc = G_nlp.concordance(fileids=homer_files[:2], basis="lemma")

print(f"Unique lemmas: {len(conc)}")
print("\nMost cited lemmas:")
top_lemmas = sorted(conc.items(), key=lambda x: len(x[1]), reverse=True)[:15]
for lemma, citations in top_lemmas:
    print(f"  {lemma:20s} {len(citations):>4d} occurrences")
# Out:
# Unique lemmas: 2584
#
# Most cited lemmas:
#   ὁ                     385 occurrences
#   δʼ                    337 occurrences
#   καί                   297 occurrences
#   δέ                    216 occurrences
#   τε                    201 occurrences
#   ὅς                    121 occurrences
#   εἰμί                  119 occurrences
#   ἐγώ                   115 occurrences
#   σύ                    103 occurrences
#   μέν                    97 occurrences
#   ἀχαιός                 94 occurrences
#   ναῦς                   92 occurrences
#   γάρ                    87 occurrences
#   οὐ                     87 occurrences
#   ὡς                     79 occurrences

# %%
# KWIC by lemma - matches all inflected forms

for hit in G_nlp.kwic("θεός", fileids=homer_files[:2], by_lemma=True, window=4, limit=5):
    print(f"{hit['left']:>40s} [{hit['match']}] {hit['right']:<40s}")
    print(f"{'':>40s}  {hit['citation']}")
    print()
# Out:
#                           τίς τʼ ἄρ σφωε [θεῶν] ἔριδι ξυνέηκε μάχεσθαι ;
#                                           <hom. il. 1.7>
#
#                        Ἀχαιοί , ὑμῖν μὲν [θεοὶ] δοῖεν Ὀλύμπια δώματʼ ἔχοντες
#                                           <hom. il. 1.15>
#
#              χραίσμῃ σκῆπτρον καὶ στέμμα [θεοῖο] : τὴν δʼ ἐγὼ
#                                           <hom. il. 1.23>
#
#                   ἀνὰ στρατὸν ᾤχετο κῆλα [θεοῖο] , τῇ δεκάτῃ δʼ
#                                           <hom. il. 1.44>
#
#                         σὺ μὲν νῦν τήνδε [θεῷ] πρόες : αὐτὰρ Ἀχαιοὶ
#                                           <hom. il. 1.104>

# %%
# N-grams by lemma

print("Most common lemma bigrams in Homer (sample):")
lemma_counts = Counter(G_nlp.ngrams(n=2, fileids=homer_files[:2], basis="lemma"))
for bigram, count in lemma_counts.most_common(10):
    print(f"  {bigram}: {count}")
# Out:
# Most common lemma bigrams in Homer (sample):
#   ὁ δʼ: 99
#   ὁ δέ: 42
#   ὁ μέν: 34
#   τε καί: 29
#   ὁ γε: 18
#   δʼ ἄρʼ: 16
#   υἱός ἀχαιός: 16
#   δʼ ἅμα: 15
#   ὁ γʼ: 14
#   οὐ γάρ: 14

# %%
# find_sents() by lemma - finds ALL inflected forms

for hit in islice(G_nlp.find_sents(lemma="θεός", fileids=homer_files[:1]), 5):
    print(f"{hit['citation']}: {hit['sentence'][:80]}...")
    print(f"  Matched forms: {hit['matches']}")
    print()
# Out:
# <hom. il. 1.6>: τίς τʼ ἄρ σφωε θεῶν ἔριδι ξυνέηκε μάχεσθαι; Λητοῦς καὶ Διὸς υἱός: ὃ γὰρ βασιλῆϊ ...
#   Matched forms: ['θεῶν', 'θεοὶ']
#
# <hom. il. 1.18>: ἔνθʼ ἄλλοι μὲν πάντες ἐπευφήμησαν Ἀχαιοὶ αἰδεῖσθαί θʼ ἱερῆα καὶ ἀγλαὰ δέχθαι ἄπο...
#   Matched forms: ['θεοῖο']
#
# <hom. il. 1.43>: ἐννῆμαρ μὲν ἀνὰ στρατὸν ᾤχετο κῆλα θεοῖο, τῇ δεκάτῃ δʼ ἀγορὴν δὲ καλέσσατο λαὸν ...
#   Matched forms: ['θεοῖο']
#
# <hom. il. 1.104>: ἀλλὰ σὺ μὲν νῦν τήνδε θεῷ πρόες: αὐτὰρ Ἀχαιοὶ τριπλῇ τετραπλῇ τʼ ἀποτείσομεν, αἴ...
#   Matched forms: ['θεῷ']
#
# <hom. il. 1.143>: ἔχθιστος δέ μοί ἐσσι διοτρεφέων βασιλήων: αἰεὶ γάρ τοι ἔρις τε φίλη πόλεμοί τε μ...
#   Matched forms: ['θεός']

# %% [markdown]
# ## Annotation levels

# %%
# AnnotationLevel controls NLP processing overhead
# NONE     - texts() only (fastest, no spaCy)
# TOKENIZE - tokenization + sentence boundaries (spacy.blank('grc'))
# BASIC    - + lemmatization, POS tagging (OdyCy, disable parser/NER)
# FULL     - full pipeline including NER and deps (OdyCy)

print("Available annotation levels:")
for level in AnnotationLevel:
    print(f"  {level.name}: {level.value}")
# Out:
# Available annotation levels:
#   NONE: none
#   TOKENIZE: tokenize
#   BASIC: basic
#   FULL: full
